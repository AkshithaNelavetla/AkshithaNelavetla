# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pdsdataframe1 = pd.read_csv(r"/pds1.csv")
pdsdataframe1
# Out:
#    Height (Inches)  Weight (Pounds)   Age  Grip strength Frailty
# 0             65.8               112   30             30       N
# 1             71.5               136   19             31       N
# 2             69.4               153   45             29       N
# 3             68.2               142   22             28       Y
# 4             67.8               144   29             24       Y
# 5             68.7               123   50             26       N
# 6             69.8               141   51             22       Y
# 7             70.1               136   23             20       Y
# 8             67.9               112   17             19       N
# 9             66.8               120   39             31       N

# %%
print("Shape:", pdsdataframe1.shape, "\n") # Replace df with pdsdataframe1
pdsdataframe1.dtypes
# Out:
# Shape: (10, 5)
# Height (Inches)     float64
# Weight (Pounds)       int64
# Age                   int64
# Grip strength         int64
# Frailty              object
# dtype: object

# %%
pdsdataframe1.columns=['Height', 'Weight', 'Age', 'Grip Strength','Frailty']
pdsdataframe1.columns
pdsdataframe1['Frailty'].replace(['Y', 'N'], [1, 0], inplace=True)
pdsdataframe1
# Out:
# <ipython-input-5-de0e46e26e5c>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   pdsdataframe1['Frailty'].replace(['Y', 'N'], [1, 0], inplace=True)
# <ipython-input-5-de0e46e26e5c>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pdsdataframe1['Frailty'].replace(['Y', 'N'], [1, 0], inplace=True)
#    Height  Weight  Age  Grip Strength  Frailty
# 0    65.8     112   30             30        0
# 1    71.5     136   19             31        0
# 2    69.4     153   45             29        0
# 3    68.2     142   22             28        1
# 4    67.8     144   29             24        1
# 5    68.7     123   50             26        0
# 6    69.8     141   51             22        1
# 7    70.1     136   23             20        1
# 8    67.9     112   17             19        0
# 9    66.8     120   39             31        0

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Frailty', data=pdsdataframe1)
plt.title('Frailty Distribution')
plt.show()
